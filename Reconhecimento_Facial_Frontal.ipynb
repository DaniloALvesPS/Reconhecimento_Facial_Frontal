# %% [markdown]
# <a href="https://colab.research.google.com/github/DaniloALvesPS/Reconhecimento_Facial_Frontal/blob/main/Reconhecimento_Facial_Frontal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2

# %%
imagem = cv2.imread("Outras-pessoas.jpg")

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(imagem)
# Out:
# <PIL.Image.Image image mode=RGB size=1000x480 at 0x7F30FFF129A0>

# %%
detector_face = cv2.CascadeClassifier('/content/haarcascade_frontalface_default.xml')

# %%
imagem_cinza = cv2.cvtColor(imagem, cv2.COLOR_BGR2GRAY)
cv2_imshow(imagem_cinza)
# Out:
# <PIL.Image.Image image mode=L size=1000x480 at 0x7F30FFF12910>

# %%
deteccoes = detector_face.detectMultiScale(imagem_cinza, scaleFactor=1.3, minSize=(30,30))

# %%
deteccoes
# Out:
# array([[510,  71,  57,  57],
#        [147,  33,  75,  75],
#        [681,  95,  73,  73],
#        [350,  12,  69,  69],
#        [348, 155,  72,  72],
#        [737, 148,  85,  85],
#        [242, 150,  87,  87],
#        [567, 220,  85,  85],
#        [346, 285,  85,  85]], dtype=int32)

# %%
len(deteccoes)
# Out:
# 9

# %%
for ( x, y, l, a) in deteccoes:
  #printe(x,y,l,a)
  cv2.rectangle(imagem,(x,y), (x + l,y + a), (0,255,0), 2)
cv2_imshow(imagem)
# Out:
# <PIL.Image.Image image mode=RGB size=1000x480 at 0x7F30FFF12910>
